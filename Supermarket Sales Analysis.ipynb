# %% [markdown]
# ### Importing the Important libraries

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # Visualize the Data
import seaborn as sns
import warnings
warnings.filterwarnings("ignore") #Never display warnings

# %% [markdown]
# ### Read the Data set

# %%
df=pd.read_csv("market.csv")
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ### What will do in this data set

# %% [markdown]
# 1.Relation of customers with SuperMarket
#
# 2.Payment methods used in supermarket.
#
# 3.Products relation with quantities.
#
# 4.Types of product and their sales.
#
# 5.Products and their ratings.

# %% [markdown]
# ### EDA Benefits  (Exploratory Data Analysis) ----> it is an iterative process

# %% [markdown]
# 1.Model building-----> Make Predictions Model
#
# 2.Analysis and reporting ----> Extraction of Data and Make Report
#
# 3.Validate assumptions
#
# 4.Handling missing values ------> Solve the mising value (Remove, fill the value)
#
# 5.feature engineering ---------> Colume help for predicting the data or add the new column if required
#
# 6.detecting outliers ----------> outier are affect our mean value or it disturb the data set accuracy

# %% [markdown]
# ### Column Types

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# 1  226-31-3081      C  Naypyitaw        Normal  Female
# 2  631-41-3108      A     Yangon        Normal    Male
# 3  123-19-1176      A     Yangon        Member    Male
# 4  373-73-7910      A     Yangon        Normal    Male
#
#              Product line  Unit price  Quantity   Tax 5%     Total       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross margin percentage  gross income  Rating
# 0  13:08      Ewallet  522.83                 4.761905       26.1415     9.1
# ...

# %% [markdown]
# Numerical - Unit price, Quantity, Tax 5%, Total, Cogs(Cost Of Goods Sold),Gross margin percentage, gross income
#
# Categorical - Branch,Customer Type,Gender,Payment,city, Product line, Rating
#
# Mixed - Invoice Id,Date, Time

# %% [markdown]
# ### Univariate Analysis ---> Anlysis of independent  column

# %% [markdown]
# ##### 1.Distribution Analysis

# %% [markdown]
# To identify its
#
# shape ---->Normal Distribution & Skewed Distribution
#
# central tendency ----> It use to find mean, median, or mode
#
# dispersion ---->Data set are spread out from the central tendency

# %% [markdown]
# ##### 2. Identifying potential issues

# %% [markdown]
# Problems with the data such as outliers, skewness, and missing values

# %% [markdown]
# # 1. Steps of doing Univariate Analysis on Numerical columns / Categorical Column

# %% [markdown]
# Descriptive Statistics
#
# Visualizations
#
# Identifying Outliers
#
# Skewness
#
# Conclusion

# %% [markdown]
# ### Unit price

# %%
df['Unit price'].describe()
# Out:
# count    1000.000000
# mean       55.672130
# std        26.494628
# min        10.080000
# 25%        32.875000
# 50%        55.230000
# 75%        77.935000
# max        99.960000
# Name: Unit price, dtype: float64

# %%
df['Unit price'].plot(kind='hist',bins=20)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['Unit price'].plot(kind='kde')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df['Unit price'].skew()
# Out:
# 0.007077447853328846

# %%
df['Unit price'].plot(kind='box') # Find the Outliers
# Out:
# <AxesSubplot:>

# %%
#Check mising value
df['Unit price'].isnull().sum()
# Out:
# 0

# %% [markdown]
# #Conclusion
#
# 1 Unit price is normally(almost) distributed
#
# 2.There are no  missing value
#
# 3.There are no outliers

# %% [markdown]
# ### Branch

# %%
df['Branch'].value_counts()
# Out:
# A    340
# B    332
# C    328
# Name: Branch, dtype: int64

# %%
df['Branch'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
df['Branch'].value_counts().plot(kind='pie',autopct='%0.1f%%')
# Out:
# <AxesSubplot:ylabel='Branch'>

# %%
df['Branch'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Conclusion
#
# There is no mising value

# %% [markdown]
# # Steps of doing Bivariate Analysis/ Multivariate Analysis

# %% [markdown]
# Numerical - Numerical
#
# a. You can plot graphs like scatterplot(regression plots), 2D histplot, 2D KDEplots
#
# b. Check correlation coefficent to check linear relationship
#
# Numerical - Categorical
#
# create visualizations that compare the distribution of the numerical data across different categories of the categorical data.
#
# a. You can plot graphs like barplot, boxplot, kdeplot violinplot even scatterplots
#
# Categorical - Categorical
#
# a. You can create cross-tabulations or contingency tables that show the distribution of values in one categorical column, grouped by the values in the other categorical column.
#
# b. You can plots like heatmap, stacked barplots, treemaps
#
# Write your conclusions

# %% [markdown]
# # EDA

# %%
df
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 0    750-67-8428      A     Yangon        Member  Female
# 1    226-31-3081      C  Naypyitaw        Normal  Female
# 2    631-41-3108      A     Yangon        Normal    Male
# 3    123-19-1176      A     Yangon        Member    Male
# 4    373-73-7910      A     Yangon        Normal    Male
# ..           ...    ...        ...           ...     ...
# 995  233-67-5758      C  Naypyitaw        Normal    Male
# 996  303-96-2227      B   Mandalay        Normal  Female
# 997  727-02-1313      A     Yangon        Member    Male
# 998  347-56-2442      A     Yangon        Normal    Male
# 999  849-09-3807      A     Yangon        Member  Female
#
#                Product line  Unit price  Quantity   Tax 5%      Total  \
# 0         Health and beauty       74.69         7  26.1415   548.9715
# 1    Electronic accessories       15.28         5   3.8200    80.2200
# ...

# %% [markdown]
# ### 1.Data Cleaning

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %% [markdown]
# There is no missing value
#
# The data set is clean so we will continue with data visualization

# %% [markdown]
# ### 2.Checking information of data set

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Total        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count             1.000000e+03   1000.000000  1000.00000
# mean              4.761905e+00     15.379369     6.97270
# std               6.131498e-14     11.708825     1.71858
# min               4.761905e+00      0.508500     4.00000
# ...

# %% [markdown]
# ### 3.Checking number of rows and columns

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# ## Visualization

# %% [markdown]
# #### Using the visualization tools to check different aspects of Supermarket sales

# %% [markdown]
# ### Gender Count

# %%
plt.figure(figsize=(14,6))
gc= sns.countplot('Gender', data=df , palette = 'copper')
gc.set_xlabel(xlabel= "Gender",fontsize=18)
gc.set_ylabel(ylabel = "Gender count", fontsize = 18)
gc.set_title(label = "Gender count in supermarket", fontsize = 20)
plt.show()

# %% [markdown]
# Conclusion: number of males and females entering the store is almost equal

# %%
#Check the Numerical data
df.groupby(['Gender']). agg({'Total':'sum'})
# Out:
#              Total
# Gender
# Female  167882.925
# Male    155083.824

# %% [markdown]
# Conclusion: Visualise and numerical data almost same

# %% [markdown]
# # Customer type

# %%
plt.figure(figsize= (14,6))
ct= sns.countplot(x = "Customer type", data = df, palette = "rocket_r")
ct.set_title("Type of customers", fontsize = 25)
ct.set_xlabel("Customer type", fontsize = 16)
ct.set_ylabel("Customer Count", fontsize = 16)
plt.show()

# %% [markdown]
# Conclusion: number of member and normal entering the store is almost equal

# %%
#Check the Numerical data
df.groupby(['Customer type']). agg({'Total':'sum'})
# Out:
#                     Total
# Customer type
# Member         164223.444
# Normal         158743.305

# %% [markdown]
# ### Check for different branch

# %%
plt.figure(figsize=(14,6))
bh = sns.countplot(x = "Customer type", hue = "Branch", data = df, palette= "rocket_r")
bh.set_title(label = "Customer type in different branch", fontsize = 20)
bh.set_xlabel(xlabel = "Branches", fontsize = 16)
bh.set_ylabel(ylabel = "Customer Count", fontsize = 16)
plt.show()

# %% [markdown]
# ### Checking the different payment methods

# %%
plt.figure(figsize = (14,6))
pm = sns.countplot(x = "Payment", data = df, palette = "tab20")
pm.set_title(label = "Payment methods of customers ", fontsize= 25)
pm.set_xlabel(xlabel = "Payment method", fontsize = 16)
pm.set_ylabel(ylabel = " Customer Count", fontsize = 16)
plt.show()

# %% [markdown]
# ### Payment distribution method in all branches

# %%
plt.figure(figsize = (14,6))
pdm= sns.countplot(x="Payment", hue = "Branch", data = df, palette= "tab20")
pdm.set_title(label = "Payment distribution in all branches", fontsize= 25)
pdm.set_xlabel(xlabel = "Payment method", fontsize = 16)
pdm.set_ylabel(ylabel = "Peple Count", fontsize = 16)
plt.show()

# %% [markdown]
# ### Rating distribution in all branches

# %%
plt.figure(figsize=(14,6)) 
rdb = sns.boxplot(x="Branch", y = "Rating" ,data =df, palette= "RdYlBu")
rdb.set_title("Rating distribution between branches", fontsize = 25)
rdb.set_xlabel(xlabel = "Branches", fontsize = 16)
rdb.set_ylabel(ylabel = "Rating distribution", fontsize = 16)
plt.show()

# %%
plt.figure(figsize = (18,10))
rdb= sns.countplot(x="Branch", hue = "Rating", data = df, palette= "tab20")
rdb.set_title("Rating distribution between branches", fontsize = 25)
rdb.set_xlabel(xlabel = "Branches", fontsize = 16)
rdb.set_ylabel(ylabel = "Rating distribution", fontsize = 16)
plt.show()

# %% [markdown]
# Conclusion: A & C Avarge rating is more then 7 and B is less then 7  (From Box Plot)

# %% [markdown]
# ### Max sales time

# %%
df["Time"]= pd.to_datetime(df["Time"])
df["Hour"]= (df["Time"]).dt.hour
plt.figure(figsize=(14,6))
SalesTime = sns.lineplot(x="Hour", y ="Quantity", data = df).set_title("product sales per Hour")
plt.show()

# %% [markdown]
# Conclusion: Most of it’s sells in 14:00 hrs

# %% [markdown]
# ### Using boxen plot

# %%
plt.figure(figsize=(10,6))
qp = sns.boxenplot(x = "Quantity", y = "Product line", data = df,)
qp.set_title(label = "Average sales of different lines of products", fontsize = 25)
qp.set_xlabel(xlabel = "Qunatity Sales",fontsize = 16)
qp.set_ylabel(ylabel = "Product Line", fontsize = 16)
plt.show()

# %% [markdown]
# Conclusion: Health and beauty product, highest sales whereas Fashon accessories product the lowest sales

# %% [markdown]
# ### Average ratings of products

# %%
plt.figure(figsize = (14,6))
ar = sns.boxenplot(y = "Product line", x = "Rating", data = df)
ar.set_title("Average rating of product line", fontsize = 25)
ar.set_xlabel("Rating", fontsize = 16)
ar.set_ylabel("Product line", fontsize = 16)
plt.show()

# %% [markdown]
# Conclusion: Health, Beauty, Food & Beverage average rating is more then 7

# %% [markdown]
# # Identify the Outliers

# %%
plt.figure(figsize=(6,6),dpi=90)
sns.boxplot(data=df,x="Total",y="Payment")
plt.grid()

# %%
df[(df.Payment=="Credit card") & (df.Total>1000)]
# Out:
#       Invoice ID Branch       City Customer type  Gender         Product line  \
# 167  687-47-8271      A     Yangon        Normal    Male  Fashion accessories
# 350  860-79-0874      C  Naypyitaw        Member  Female  Fashion accessories
# 422  271-88-8734      C  Naypyitaw        Member  Female  Fashion accessories
# 792  744-16-7898      B   Mandalay        Normal  Female   Home and lifestyle
#
#      Unit price  Quantity  Tax 5%     Total       Date                Time  \
# 167       98.98        10  49.490  1039.290   2/8/2019 2023-02-05 16:20:00
# 350       99.30        10  49.650  1042.650  2/15/2019 2023-02-05 14:53:00
# 422       97.21        10  48.605  1020.705   2/8/2019 2023-02-05 13:00:00
# 792       97.37        10  48.685  1022.385  1/15/2019 2023-02-05 13:48:00
#
#          Payment   cogs  gross margin percentage  gross income  Rating  Hour
# 167  Credit card  989.8                 4.761905        49.490     8.7    16
# ...

# %%
df.drop([167,350,422,792],axis=0,inplace=True)

# %%
df[(df.Payment=="Ewallet") & (df.Total>1000)]
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 557  283-26-5248      C  Naypyitaw        Member  Female  Food and beverages
# 699  751-41-9720      C  Naypyitaw        Normal    Male  Home and lifestyle
# 996  303-96-2227      B   Mandalay        Normal  Female  Home and lifestyle
#
#      Unit price  Quantity  Tax 5%    Total       Date                Time  \
# 557       98.52        10   49.26  1034.46  1/30/2019 2023-02-05 20:23:00
# 699       97.50        10   48.75  1023.75  1/12/2019 2023-02-05 16:18:00
# 996       97.38        10   48.69  1022.49   3/2/2019 2023-02-05 17:16:00
#
#      Payment   cogs  gross margin percentage  gross income  Rating  Hour
# 557  Ewallet  985.2                 4.761905         49.26     4.5    20
# 699  Ewallet  975.0                 4.761905         48.75     8.0    16
# 996  Ewallet  973.8                 4.761905         48.69     4.4    17

# %%
df.drop([557,699,996],axis=0,inplace=True)

# %%
df[(df.Payment=="Cash") & (df.Total>1000)]
# Out:
#       Invoice ID Branch       City Customer type  Gender        Product line  \
# 166  234-65-2137      C  Naypyitaw        Normal    Male  Home and lifestyle
# 357  554-42-2417      C  Naypyitaw        Normal  Female   Sports and travel
#
#      Unit price  Quantity  Tax 5%    Total       Date                Time  \
# 166       95.58        10   47.79  1003.59  1/16/2019 2023-02-05 13:32:00
# 357       95.44        10   47.72  1002.12   1/9/2019 2023-02-05 13:45:00
#
#     Payment   cogs  gross margin percentage  gross income  Rating  Hour
# 166    Cash  955.8                 4.761905         47.79     4.8    13
# 357    Cash  954.4                 4.761905         47.72     5.2    13

# %%
df.drop([166,357],axis=0,inplace=True)

# %%
plt.figure(figsize=(6,6),dpi=90)
sns.boxplot(data=df,x="Total",y="Payment")
plt.grid()

# %%
colname=df.select_dtypes(["int64","float64"]).columns
colname
# Out:
# Index(['Unit price', 'Quantity', 'Tax 5%', 'Total', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating', 'Hour'],
#       dtype='object')

# %%
df[colname]
# Out:
#      Unit price  Quantity   Tax 5%     Total    cogs  gross margin percentage  \
# 0         74.69         7  26.1415  548.9715  522.83                 4.761905
# 1         15.28         5   3.8200   80.2200   76.40                 4.761905
# 2         46.33         7  16.2155  340.5255  324.31                 4.761905
# 3         58.22         8  23.2880  489.0480  465.76                 4.761905
# 4         86.31         7  30.2085  634.3785  604.17                 4.761905
# ..          ...       ...      ...       ...     ...                      ...
# 994       60.95         1   3.0475   63.9975   60.95                 4.761905
# 995       40.35         1   2.0175   42.3675   40.35                 4.761905
# 997       31.84         1   1.5920   33.4320   31.84                 4.761905
# 998       65.82         1   3.2910   69.1110   65.82                 4.761905
# 999       88.34         7  30.9190  649.2990  618.38                 4.761905
#
#      gross income  Rating  Hour
# ...

# %%
from scipy.stats import skew

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))

    sns.distplot(df[col])
    plt.show()
# Out:
# Unit price
# 0.014014765558211989
# Quantity
# 0.021840042642475428
# Tax 5%
# 0.842670203212295
# Total
# 0.8426702032122947
# cogs
# 0.8426702032122952
# gross margin percentage
# 0.0
# gross income
# 0.842670203212295
# Rating
# 0.005928660157769048
# Hour
# 0.02301705276900862

# %%
df.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_42124_row0_col0, #T_42124_row1_col1, #T_42124_row2_col2, #T_42124_row2_col3, #T_42124_row2_col4, #T_42124_row2_col6, #T_42124_row3_col2, #T_42124_row3_col3, #T_42124_row3_col4, #T_42124_row3_col6, #T_42124_row4_col2, #T_42124_row4_col3, #T_42124_row4_col4, #T_42124_row4_col6, #T_42124_row6_col2, #T_42124_row6_col3, #T_42124_row6_col4, #T_42124_row6_col6, #T_42124_row7_col7, #T_42124_row8_col8 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_42124_row0_col1, #T_42124_row1_col0, #T_42124_row2_col7, #T_42124_row3_col7, #T_42124_row4_col7, #T_42124_row6_col7, #T_42124_row7_col1, #T_42124_row7_col2, #T_42124_row7_col3, #T_42124_row7_col4, #T_42124_row7_col6, #T_42124_row7_col8, #T_42124_row8_col1, #T_42124_row8_col7 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_42124_row0_col2, #T_42124_row0_col3, #T_42124_row0_col4, #T_42124_row0_col6 {
#   background-color: #328dbf;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# skew ----> Close to zero
#
# Correlation---> Close to one

# %% [markdown]
# Conclusion:
#
# 1) Total is Highly Skewed and correlation not close to 1
#
# 2)Cogs is highly skewed and cogs not close to 1
#
# 3)Gross income is highly skewed and not correlation not close to 1
#
# 4)Tax 5% is highly skewed and not correlation not close to 1
#
# Then use a log or sqrt are use to converted Skewed value close to zero

# %% [markdown]
# ### sqrt

# %%
df["Total"]=np.sqrt(df["Total"])
df["cogs"]=np.sqrt(df["cogs"])
df["gross income"]=np.sqrt(df["gross income"])
df["Tax 5%"]=np.sqrt(df["Tax 5%"])

# %%
for col in df[colname]:
    print(col)
    print(skew(df[col]))

    sns.distplot(df[col])
    plt.show()
# Out:
# Unit price
# 0.014014765558211989
# Quantity
# 0.021840042642475428
# Tax 5%
# 0.24071803685334658
# Total
# 0.24071803685334792
# cogs
# 0.24071803685334714
# gross margin percentage
# 0.0
# gross income
# 0.24071803685334658
# Rating
# 0.005928660157769048
# Hour
# 0.02301705276900862

# %%
sns.pairplot(df)
plt.show()

# %%
sns.heatmap(df.corr())
plt.show()
